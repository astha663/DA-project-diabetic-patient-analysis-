# %% [markdown]
# # Week 5 Assignment :-

# %% [markdown]
# ## Importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression

# %% [markdown]
# ## Importing Dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
data=pd.read_csv('diabetes.csv')
features = ['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI', 'DiabetesPedigreeFunction', 'Age']
ROWS, COLS = 2, 4
fig, ax = plt.subplots(ROWS, COLS, figsize=(18,8) )
row, col = 0, 0
for i, feature in enumerate(features):
    if col == COLS - 1:
        row += 1
    col = i % COLS
    
    data[feature].hist(bins=35, color='red', alpha=0.5, ax=ax[row, col]).set_title(feature)

# %%
features = ['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI', 'DiabetesPedigreeFunction', 'Age']
ROWS, COLS = 2, 4
fig, ax = plt.subplots(ROWS, COLS, figsize=(18,8) )
row, col = 0, 0
for i, feature in enumerate(features):
    if col == COLS - 1:
        row += 1
    col = i % COLS
    
    df[feature].hist(bins=35, color='green', alpha=0.5, ax=ax[row, col]).set_title(feature)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-8df1a08b0793> in <module>
#       8     col = i % COLS
#       9
# ---> 10     df[feature].hist(bins=35, color='green', alpha=0.5, ax=ax[row, col]).set_title(feature)
#
# NameError: name 'df' is not defined

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestClassifier
data=pd.read_csv('diabetes.csv')
df=pd.DataFrame(data)
X, y = df.drop('Outcome', axis=1), df['Outcome']
rfc = RandomForestClassifier(n_estimators=100)
rfc_model = rfc.fit(X, y)
(pd.Series(rfc_model.feature_importances_, index=X.columns)
    .nlargest(8)
    .plot(kind='barh', colors = ["r","g","b"],figsize=[8,4])
    .invert_yaxis())
plt.yticks(size=15)
plt.title('Top Features derived by Random Forest', size=20)

# %% [markdown]
# ### The last 10 values of a data set

# %%
data.tail(10)

# %% [markdown]
# ## Description of dataset

# %%
data.describe()

# %%
data.shape

# %%
data.info()

# %%
for i in data.columns:
    print(i,len(data[i].unique()))

# %% [markdown]
# ##  Univariate  and Bivariate analysis of data

# %% [markdown]
# ## Bivariate analysis
# ### we are going to plot a bar chart with  two variable

# %%
sns.barplot('Outcome','Age',data=data)
plt.xlabel('Outcome(0-no diabetes,1-diabetes)')
plt.title('Age vs Outcome')

# %%
sns.FacetGrid(data,hue="data",size=5).map(sns.distplot,"Age").add_legend()

# %% [markdown]
# ## univariate analysis
# ### we are going to plot a pie chart with single variable

# %%
a,b=np.unique(data.Glucose.values,return_counts=True)
colors = ['#f8e100','#f4178a']
labels=['Glucose','BMI']
plt.pie([b[0],b[1]],colors=colors,labels=labels,autopct='%1.1f%%',shadow=True)
plt.show()

# %% [markdown]
# ## Checking missing values in data set

# %%
data.isnull().sum()

# %%
data.Outcome.unique()

# %% [markdown]
# ## Removing columns those contains null values

# %%
data.drop('Outcome',axis=1,inplace=True)
data.shape

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
d=pd.read_csv('diabetes.csv')
d=d.groupby('Age')["Age"].count()
sns.scatterplot(x=d.index,y=d)
plt.xlabel("Age")
plt.ylabel("No. of entries")
plt.title("Ages Vs Entries graph")
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
d=pd.read_csv('diabetes.csv')
d=sns.FacetGrid(d,col='Outcome')
d=d.map(sns.distplot,"Age")
plt.show()

# %% [markdown]
# ## Data Formatting

# %% [markdown]
# ## replacing zero values with mean of attributes ,There are zero values in a Glucose,Blood Pressure,SkinThickness and BMI

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
data=pd.read_csv('diabetes.csv')
data.Glucose.replace(0,np.nan,inplace=True)
data.Glucose.replace(np.nan,data['Glucose'].median(),inplace=True)
data.BloodPressure.replace(0,np.nan,inplace=True)
data.BloodPressure.replace(np.nan,data['BloodPressure'].median(),inplace=True)
data.SkinThickness.replace(0,np.nan,inplace=True)
data.SkinThickness.replace(np.nan,data['SkinThickness'].median(),inplace=True)
data.Insulin.replace(0,np.nan,inplace=True)
data.Insulin.replace(np.nan,data['Insulin'].median(),inplace=True)
data.BMI.replace(0,np.nan,inplace=True)
data.BMI.replace(np.nan,data['BMI'].median(),inplace=True)
features = ['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI', 'DiabetesPedigreeFunction', 'Age']
ROWS, COLS = 2, 4
fig, ax = plt.subplots(ROWS, COLS, figsize=(18,8) )
row, col = 0, 0
for i, feature in enumerate(features):
    if col == COLS - 1:
        row += 1
    col = i % COLS
    
    df[feature].hist(bins=35, color='green', alpha=0.5, ax=ax[row, col]).set_title(feature)

# %%
data.head(10)

# %%
x_multi = [np.random.randn(n) for n in [10000, 5000, 2000]]
ax3.hist(x_multi, n_bins, histtype='bar')
ax3.set_title('different sample sizes')

fig.tight_layout()
plt.show(

# %%
correlation=data.corr()
correlation

# %%
plt.subplots(figsize=(10,7))
sns.heatmap(correlation,center=0,cmap="Accent",annot=True)

# %%
sns.pairplot(data)

# %%
sns.set_style('whitegrid')
sns.distplot(data['Age'],color='r',rug=False,bins=30)
