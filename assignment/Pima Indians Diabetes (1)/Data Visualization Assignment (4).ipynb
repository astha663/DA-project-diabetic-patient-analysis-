# %% [markdown]
# # Data Analysis and Machine Learning Using Python

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Data Visualization Assignment

# %% [markdown]
# ### Submission Date & Time : 21st June 2020 & 15:00

# %% [markdown]
# ## Q.1
# - Import all modules required for Data Visualization

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ## Q.2
# - Plot a Sine Wave with color code with "black" color and style as dashdot, also mark "x" and "y" label and give a suitable title to it

# %%
x=np.arange(0,12,2.1)
plt.plot(x,np.sin(x),color='#000304',linestyle='-.')
plt.title("Sine Wave Curve")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
# Out:
# Text(0, 0.5, 'Y-axis')

# %% [markdown]
# ## Q.3
# - Plot a line curve with list=[2,3,4,5], use linestyle and color together for the graph and marker style as "Rotated Hexagon Marker"

# %%
list=[2,3,4,5]
plt.plot(list,color='#ffa600',linestyle='-',marker='h')

# %% [markdown]
# ## Q.4
# ![image.png](attachment:image.png)
# -Plot Stacked Bar Graph for the above data.
#     - Use proper colors and x and y label for the graph
#     - Use legend positioned at upper right corner
#     - Also mark xticks with an angle of 90 Degree

# %%
store=['Delhi','Mumbai','Chennai','Kolkata','Hyderabad']
Clothing=np.array([82,78,48,46,39])
Equipment=np.array([48,31,51,29,18])
Accessories=np.array([15,20,14,13,9])
ind=[z for z, _ in enumerate(store)]
plt.bar(ind,Clothing,width=0.5,label='Clothing',color='#d45087',bottom=Equipment+Accessories)
plt.bar(ind,Equipment,width=0.5,label='Equipments',color='#54a739',bottom=Accessories)
plt.bar(ind,Accessories,width=0.5,label='Accessories',color='#ffa600')
plt.xticks(ind,store,rotation=90,Horizontalalignment="right")
plt.xlabel("Metropolis(city)" ,color="#1f2cb1")
plt.ylabel("Stores",color="#1f2cb1")
plt.legend(loc='upper right',fancybox=True, framealpha=0.8, shadow=True, borderpad=1,title='stores in cities')
plt.title("Shops among various Metropolis")
# Out:
# Text(0.5, 1.0, 'Shops among various Metropolis')

# %% [markdown]
# ## Q.5 For Titanic Dataset
# - Load Dataset using Seaborn
# - Plot a Bar Graph of Survival of Passenger against the Passenger Class.
# - Use proper "hue" attribute, and palette color. Mark 'x' and 'y' label with proper title.
# - Use legend located at upper left corner

# %%
print(sns.get_dataset_names(),end=" ")
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\utils.py:376: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 376 of the file C:\ProgramData\Anaconda3\lib\site-packages\seaborn\utils.py. To get rid of this warning, pass the additional argument 'features="lxml"' to the BeautifulSoup constructor.
#
#   gh_list = BeautifulSoup(http)
# ['anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'exercise', 'flights', 'fmri', 'gammas', 'geyser', 'iris', 'mpg', 'penguins', 'planets', 'tips', 'titanic']

# %%
data=sns.load_dataset('titanic')
data.head(6)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
# 5         0       3    male   NaN      0      0   8.4583        Q  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True
# 5    man        True  NaN   Queenstown    no   True

# %%
survive=sns.countplot(x='pclass',hue='survived',palette='Set1',data=data)
survive.set(title='Survival of passenger against the Passenger class')
plt.legend(loc="upper left",fancybox=True, framealpha=0.8, shadow=True, borderpad=1,title='survival vs pclass')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-181-aa1256fcfaa0> in <module>
# ----> 1 survive=sns.countplot(x='pclass',hue='survived',palette='Set1',data=data)
#       2 survive.set(title='Survival of passenger against the Passenger class')
#       3 plt.legend(loc="upper left",fancybox=True, framealpha=0.8, shadow=True, borderpad=1,title='survival vs pclass')
#       4 plt.show()
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py in countplot(x, y, hue, data, order, hue_order, orient, color, palette, saturation, dodge, ax, **kwargs)
#    3551                           estimator, ci, n_boot, units,
#    3552                           orient, color, palette, saturation,
# -> 3553                           errcolor, errwidth, capsize, dodge)
#    3554
#    3555     plotter.value_label = "count"
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py in __init__(self, x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge)
#    1605         """Initialize the plotter."""
#    1606         self.establish_variables(x, y, hue, data, orient,
# -> 1607                                  order, hue_order, units)
#    1608         self.establish_colors(color, palette, saturation)
#    1609         self.estimate_statistic(estimator, ci, n_boot)
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py in establish_variables(self, x, y, hue, data, orient, order, hue_order, units)
#     144             # See if we need to get variables from `data`
#     145             if data is not None:
# --> 146                 x = data.get(x, x)
#     147                 y = data.get(y, y)
#     148                 hue = data.get(hue, hue)
#
# AttributeError: 'AxesSubplot' object has no attribute 'get'

# %% [markdown]
# ## Q.6 For Tips Dataset
# - Load the Dataset Using Seaborn
# - Plot the Horizontal Distribution Graph on Total Bill with color as Green
# - Mark proper 'x' and 'y' label and give a suitable title

# %%
tip=sns.load_dataset('tips')
tip.head(8)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# 5       25.29  4.71    Male     No  Sun  Dinner     4
# 6        8.77  2.00    Male     No  Sun  Dinner     2
# 7       26.88  3.12    Male     No  Sun  Dinner     4

# %%
sns.distplot(tip['total_bill'],vertical=True,color='#1c9326').set_title("Distribution of Total Bill")
sns.set_style('whitegrid')

# %% [markdown]
# # Q.7
# - Also plot the KDE Graph for the above data

# %%
data = sns.kdeplot(tip['total_bill'], shade=True, color="m")

# %% [markdown]
# ## Q.8 For Cancer Dataset
# - Load the data with the help of Matplotlib (Dataset Provided)
# - Print the first 10 data of the whole dataset
# - Plot Box Plot with column 'texture_mean' , separated by column 'diagnosis'

# %%
df=pd.read_csv("Cancer.csv")
df.head(10)
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
# 5    843786         M        12.45         15.70           82.57      477.1
# 6    844359         M        18.25         19.98          119.60     1040.0
# 7  84458202         M        13.71         20.83           90.20      577.9
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760         0.30010              0.14710
# 1          0.08474           0.07864         0.08690              0.07017
# 2          0.10960           0.15990         0.19740              0.12790
# 3          0.14250           0.28390         0.24140              0.10520
# 4          0.10030           0.13280         0.19800              0.10430
# 5          0.12780           0.17000         0.15780              0.08089
# 6          0.09463           0.10900         0.11270              0.07400
# 7          0.11890           0.16450         0.09366              0.05985
#
#    ...  radius_worst  texture_worst  perimeter_worst  area_worst  \
# 0  ...         25.38          17.33           184.60      2019.0
# 1  ...         24.99          23.41           158.80      1956.0
# 2  ...         23.57          25.53           152.50      1709.0
# 3  ...         14.91          26.50            98.87       567.7
# 4  ...         22.54          16.67           152.20      1575.0
# 5  ...         15.47          23.75           103.40       741.6
# 6  ...         22.88          27.66           153.20      1606.0
# 7  ...         17.06          28.14           110.60       897.0
#
#    smoothness_worst  compactness_worst  concavity_worst  concave points_worst  \
# 0            0.1622             0.6656           0.7119                0.2654
# 1            0.1238             0.1866           0.2416                0.1860
# 2            0.1444             0.4245           0.4504                0.2430
# 3            0.2098             0.8663           0.6869                0.2575
# 4            0.1374             0.2050           0.4000                0.1625
# 5            0.1791             0.5249           0.5355                0.1741
# 6            0.1442             0.2576           0.3784                0.1932
# 7            0.1654             0.3682           0.2678                0.1556
#
#    symmetry_worst  fractal_dimension_worst
# 0          0.4601                  0.11890
# 1          0.2750                  0.08902
# 2          0.3613                  0.08758
# 3          0.6638                  0.17300
# 4          0.2364                  0.07678
# 5          0.3985                  0.12440
# 6          0.3063                  0.08368
# 7          0.3196                  0.11510
#
# [8 rows x 32 columns]

# %%
df.boxplot(column='texture_mean',by='diagnosis')

# %% [markdown]
# ## Q.9
# ![image.png](attachment:image.png)
#
# - Plot the Pie Chart for the two colums with some explode for the country "India"  and proper shadow

# %%
Country='US','Great Britain','India','Russia','Germany'
Medal=np.array([46,27,26,19,17])
colors=['#5ad828','#ffe91b','#ff3e01','#270bff','#ff0094']
explode=(0,0,0,0,0)
plt.pie(Medal,explode=explode,labels=Country,colors=colors,shadow=True,autopct='%1.2f%%',startangle=90, wedgeprops={"edgecolor":"cyan",'linewidth': 1,
                    'linestyle': 'dashed', 'antialiased': True})
plt.legend( Country,title="Acheivement",loc="best")
plt.axis('equal')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Q.10 For Tips Dataset
# - Load the dataset using seaborn
# - Draw the Strip Plot between 'total bill' and 'day'
# - Rotate xticks with an angle of 45 Degree

# %%
tip=sns.load_dataset('tips')
tip.head(8)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# 5       25.29  4.71    Male     No  Sun  Dinner     4
# 6        8.77  2.00    Male     No  Sun  Dinner     2
# 7       26.88  3.12    Male     No  Sun  Dinner     4

# %%
sns.stripplot(x='day',y='total_bill',data=tip,jitter=1)
plt.title('Graph between toal_bill and day')
plt.xticks(rotation=45)
# Out:
# (array([0, 1, 2, 3]), <a list of 4 Text xticklabel objects>)
