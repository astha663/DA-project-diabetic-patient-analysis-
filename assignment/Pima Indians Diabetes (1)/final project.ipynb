# %% [markdown]
# ## Import library
# # here we will import all library

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
function=pd.read_csv("diabetes.csv", header=None)
function
# Out:
#                0        1              2              3        4     5  \
# 0    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI
# 1              6      148             72             35        0  33.6
# 2              1       85             66             29        0  26.6
# 3              8      183             64              0        0  23.3
# 4              1       89             66             23       94  28.1
# ..           ...      ...            ...            ...      ...   ...
# 764           10      101             76             48      180  32.9
# 765            2      122             70             27        0  36.8
# 766            5      121             72             23      112  26.2
# 767            1      126             60              0        0  30.1
# 768            1       93             70             31        0  30.4
#
#                             6    7        8
# 0    DiabetesPedigreeFunction  Age  Outcome
# ...

# %% [markdown]
# ## Import Dataset
# # here we will import our dataset

# %%
data=pd.read_csv('diabetes.csv')
data.head(10)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
# 5            5      116             74              0        0  25.6
# 6            3       78             50             32       88  31.0
# 7           10      115              0              0        0  35.3
# 8            2      197             70             45      543  30.5
# 9            8      125             96              0        0   0.0
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# ...

# %%
data.tail(10)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 758            1      106             76              0        0  37.5
# 759            6      190             92              0        0  35.5
# 760            2       88             58             26       16  28.4
# 761            9      170             74             31        0  44.0
# 762            9       89             62              0        0  22.5
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 758                     0.197   26        0
# 759                     0.278   66        1
# 760                     0.766   22        0
# ...

# %% [markdown]
# ## Describing Dataset
#
# # here we will describe about our dataset

# %%
data.shape
# Out:
# (768, 9)

# %%
function.count()
# Out:
# 0    769
# 1    769
# 2    769
# 3    769
# 4    769
# 5    769
# 6    769
# 7    769
# 8    769
# dtype: int64

# %%
function.dtypes
# Out:
# 0    object
# 1    object
# 2    object
# 3    object
# 4    object
# 5    object
# 6    object
# 7    object
# 8    object
# dtype: object

# %%
function.axes
# Out:
# [RangeIndex(start=0, stop=769, step=1),
#  Int64Index([0, 1, 2, 3, 4, 5, 6, 7, 8], dtype='int64')]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
# Pregnancies                 768 non-null int64
# Glucose                     768 non-null int64
# BloodPressure               768 non-null int64
# SkinThickness               768 non-null int64
# Insulin                     768 non-null int64
# BMI                         768 non-null float64
# DiabetesPedigreeFunction    768 non-null float64
# Age                         768 non-null int64
# Outcome                     768 non-null int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
for i in data.columns:
 print(i,len(data[i].unique()))
# Out:
# Pregnancies 17
# Glucose 136
# BloodPressure 47
# SkinThickness 51
# Insulin 186
# BMI 248
# DiabetesPedigreeFunction 517
# Age 52
# Outcome 2

# %%
data.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %% [markdown]
# ## Univariate and Bivariate analysis of data

# %% [markdown]
# ## Bivariate analysis

# %%
sns.barplot('Outcome','Age',data=data)
plt.xlabel('Outcome(0-no diabetes,1-diabetes)')
plt.title('Age vs Outcome')
# Out:
# Text(0.5, 1.0, 'Age vs Outcome')

# %%
sns.barplot('Outcome','Insulin',data=data)
plt.xlabel('Outcome(0-no diabetes,1-diabetes)')
plt.title('Insulin vs Outcome')
# Out:
# Text(0.5, 1.0, 'Insulin vs Outcome')

# %%
sns.barplot('Outcome','BloodPressure',data=data)
plt.xlabel('Outcome(0-no diabetes,1-diabetes)')
plt.title('BloodPressure vs Outcome')
# Out:
# Text(0.5, 1.0, 'BloodPressure vs Outcome')

# %%
sns.barplot('Outcome','Glucose',data=data)
plt.xlabel('Outcome(0-no diabetes,1-diabetes)')
plt.title('Glucose vs Outcome')
# Out:
# Text(0.5, 1.0, 'Glucose vs Outcome')

# %% [markdown]
# ## Univariate Analysis

# %%
a,b=np.unique(data.Pregnancies.values,return_counts=True)
colors = ['#f8e100','#f4178a']
labels=['Pregnancies','Outcome']
plt.pie([b[0],b[1]],colors=colors,labels=labels,autopct='%1.1f%%',shadow=True)
plt.show()

# %%
a,b=np.unique(data.Age.values,return_counts=True)
colors = ['#f8e100','#f4178a']
labels=['Age','Outcome']
plt.pie([b[0],b[1]],colors=colors,labels=labels,autopct='%1.1f%%',shadow=True)
plt.show()

# %%
a,b=np.unique(data.Glucose.values,return_counts=True)
colors = ['#f8e100','#f4178a']
labels=['Glucose','Outcome']
plt.pie([b[0],b[1]],colors=colors,labels=labels,autopct='%1.1f%%',shadow=True)
plt.show()

# %%
a,b=np.unique(data.BMI.values,return_counts=True)
colors = ['#f8e100','#f4178a']
labels=['BMI','Outcome']
plt.pie([b[0],b[1]],colors=colors,labels=labels,autopct='%1.1f%%',shadow=True)
plt.show()

# %% [markdown]
# ## Checking missing values

# %%
data.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
print(data.Outcome.value_counts())
data['Outcome'].value_counts().plot(kind='bar', color='red').set_title('Diabetes Outcome')
# Out:
# 0    500
# 1    268
# Name: Outcome, dtype: int64
# Text(0.5, 1.0, 'Diabetes Outcome')

# %% [markdown]
# ## Removing columns having null value

# %%
data.drop('Outcome', axis=1,inplace=True)
data.shape
# Out:
# (768, 8)

# %% [markdown]
# ## Replacing zero values with the median of the attributes. there are zero values in
# ## Glucose, Blood Pressure, SkinThickness, BMI

# %%
data.Glucose.replace(0, np.nan, inplace=True)
data.Glucose.replace(np.nan, data['Glucose'].median(), inplace=True)
data.BloodPressure.replace(0, np.nan, inplace=True)
data.BloodPressure.replace(np.nan, data['BloodPressure'].median(), inplace=True)
data.SkinThickness.replace(0, np.nan, inplace=True)
data.SkinThickness.replace(np.nan, data['SkinThickness'].median(), inplace=True)
data.Insulin.replace(0, np.nan, inplace=True)
data.Insulin.replace(np.nan, data['Insulin'].median(), inplace=True)
data.BMI.replace(0, np.nan, inplace=True)
data.BMI.replace(np.nan, data['BMI'].median(), inplace=True)

# %%
data.head(10)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6    148.0           72.0           35.0    125.0  33.6
# 1            1     85.0           66.0           29.0    125.0  26.6
# 2            8    183.0           64.0           29.0    125.0  23.3
# 3            1     89.0           66.0           23.0     94.0  28.1
# 4            0    137.0           40.0           35.0    168.0  43.1
# 5            5    116.0           74.0           29.0    125.0  25.6
# 6            3     78.0           50.0           32.0     88.0  31.0
# 7           10    115.0           72.0           29.0    125.0  35.3
# 8            2    197.0           70.0           45.0    543.0  30.5
# 9            8    125.0           96.0           29.0    125.0  32.3
#
#    DiabetesPedigreeFunction  Age
# 0                     0.627   50
# 1                     0.351   31
# 2                     0.672   32
# 3                     0.167   21
# 4                     2.288   33
# ...

# %% [markdown]
# ## CORRELATION

# %%
s=data.corr()
s
# Out:
#                           Pregnancies   Glucose  BloodPressure  SkinThickness  \
# Pregnancies                  1.000000  0.128213       0.208615       0.081770
# Glucose                      0.128213  1.000000       0.218937       0.192615
# BloodPressure                0.208615  0.218937       1.000000       0.191892
# SkinThickness                0.081770  0.192615       0.191892       1.000000
# Insulin                      0.025047  0.419451       0.045363       0.155610
# BMI                          0.021559  0.231049       0.281257       0.543205
# DiabetesPedigreeFunction    -0.033523  0.137327      -0.002378       0.102188
# Age                          0.544341  0.266909       0.324915       0.126107
#
#                            Insulin       BMI  DiabetesPedigreeFunction  \
# Pregnancies               0.025047  0.021559                 -0.033523
# Glucose                   0.419451  0.231049                  0.137327
# ...

# %%
plt.subplots(figsize=(12,6))
sns.heatmap(s)

# %%
sns.pairplot(data)

# %%
sns.set(style='ticks')
plt.figure(figsize=(20,20))
sns.pairplot(data,hue='Outcome')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Outcome'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-27-682f804e8fa3> in <module>
#       1 sns.set(style='ticks')
# ...

# %%
print(data[data.BloodPressure == 0].shape[0])
print(data[data.BloodPressure == 0].index.tolist())
print(data[data.BloodPressure == 0].groupby('Outcome')['Age'].count())

# %%
print(data[data.Glucose == 0].shape[0])
print(data[data.Glucose == 0].index.tolist())
print(data[data.Glucose == 0].groupby('Outcome')['Age'].count())

# %%
print(data[data.SkinThickness == 0].shape[0])
print(data[data.SkinThickness == 0].index.tolist())
print(data[data.SkinThickness == 0].groupby('Outcome')['Age'].count())

# %%
print(data[data.BMI == 0].shape[0])
print(data[data.BMI == 0].index.tolist())
print(data[data.BMI == 0].groupby('Outcome')['Age'].count())

# %%
print(data[data.Insulin == 0].shape[0])
print(data[data.Insulin == 0].index.tolist())
print(data[data.Insulin == 0].groupby('Outcome')['Age'].count())

# %% [markdown]
# # Blood Pressure vs Outcome

# %%
plt.figure(figsize=(14,3))
bp = data.groupby('BloodPressure').Outcome.mean().reset_index()
sns.barplot(bp.BloodPressure, bp.Outcome)
plt.title('Rate of increase chance of being diagnosed with diabetes by blood pressure')
plt.show()

plt.figure(figsize=(18,8))
bp = data.groupby('BloodPressure').Outcome.count().reset_index()
sns.distplot(data[data.Outcome == 0]['BloodPressure'], color='turquoise', kde=False, label='0 Class')
sns.distplot(data[data.Outcome == 1]['BloodPressure'], color='coral', kde=False, label='1 Class')
plt.legend()
plt.title('No. of  people with blood pressure values')
plt.show()

# %% [markdown]
# # Glucose level

# %%
plt.figure(figsize=(15,10))
glucose = data.groupby('Glucose').Outcome.mean().reset_index()
sns.barplot(glucose.Glucose, glucose.Outcome)
plt.title('Rate of chances increasing of being diagnosed with diabetes by Glucose reading')
plt.show()

plt.figure(figsize=(15,10))
glucose = data.groupby('Glucose').Outcome.count().reset_index()
sns.distplot(data[data.Outcome == 0]['Glucose'], color='turquoise', kde=False, label='0 Class')
sns.distplot(data[data.Outcome == 1]['Glucose'], color='coral', kde=False, label='1 class')
plt.legend()
plt.title('No. of people with Glucose values')
plt.show()

# %% [markdown]
# # BMI

# %%
plt.figure(figsize=(15,5))
BMI = data.groupby('BMI').Outcome.mean().reset_index()
sns.barplot(BMI.BMI, BMI.Outcome)
plt.title('Rate  of chances increasing  being diagnosed with diabetes by BMI reading')
plt.show()

plt.figure(figsize=(15,5))
BMI = data.groupby('BMI').Outcome.count().reset_index()
sns.distplot(data[data.Outcome == 0]['BMI'], color='turquoise', kde=False, label='Class 0')
sns.distplot(data[data.Outcome == 1]['BMI'], color='coral', kde=False, label='Class 1')
plt.legend()
plt.title('No. of people with BMI values')
plt.show()

# %% [markdown]
# # Insulin

# %%
plt.figure(figsize=(15,5))
Insulin = data.groupby('Insulin').Outcome.mean().reset_index()
sns.barplot(Insulin.Insulin, Insulin.Outcome)
plt.title('Rate of chances increasing of being diagnosed with diabetes by Insulin reading')
plt.show()

plt.figure(figsize=(15,5))
Insulin = data.groupby('Insulin').Outcome.count().reset_index()
sns.distplot(data[data.Outcome == 0]['Insulin'], color='turquoise', kde=False, label='Class 0')
sns.distplot(data[data.Outcome == 1]['Insulin'], color='coral', kde=False, label='Class 1')
plt.legend()
plt.title('No.of people with Insulin values')
plt.show()

# %% [markdown]
# # Skin thickness

# %%
plt.figure(figsize=(15,5))
SkinThickness = data.groupby('SkinThickness').Outcome.mean().reset_index()
sns.barplot(SkinThickness.SkinThickness, SkinThickness.Outcome)
plt.title('Rate of chance increasing being diagnosed with diabetes by skin thickness reading')
plt.show()

plt.figure(figsize=(15,5))
SkinThickness = data.groupby('SkinThickness').Outcome.count().reset_index()
sns.distplot(data[data.Outcome == 0]['SkinThickness'], color='turquoise', kde=False, label='Class 0')
sns.distplot(data[data.Outcome == 1]['SkinThickness'], color='coral', kde=False, label='Class 1')
plt.legend()
plt.title('No. of people with Skin thickness values')
plt.show()

# %% [markdown]
# # Model Selection

# %% [markdown]
# ## Random Forest Classifier

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklrean.ensemble  import RandomForestClassifier
data=pd.read_csv('diabetes.csv')
df=pd.DataFrame(data)
X,y=df.drop('Outcome',axiz=1),df['Outcome']
rfc=RandomForestClassifier(n_estimators=100)
rfc_model=rfc.fit(X,y)
(pd.series(rfc_model.feature_importances_, index=X.columns)
    .nlargest(8)
    .plot(kind='barh',colors=["r","g","b"],figsize=[8,4])
    .invert_yaxis())
plt.yticks(size=15)
plt.title('Top Features derived by Random Forest',size=20)

# %%
from sklearn import linear_model as lm
from sklearn.tree import DecisionTreeClassifier as dtc
from sklearn.neighbors import KNeighborsClassifier as knnc
from sklearn.ensemble import RandomForestClassifier as rfc
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split 
from sklearn.metrics import accuracy_score, confusion_matrix

# %%
data_mod = data[(data.BloodPressure != 0) & (data.BMI != 0) & (data.Glucose != 0)]
train, test = train_test_split(data_mod, test_size=0.2)
print(data_mod.shape)
print(train.shape)
print(test.shape)

# %%
features = ['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness'\
            , 'BMI', 'Age', 'Insulin', 'DiabetesPedigreeFunction']
target = 'Outcome'
classifiers = [
    knnc(),
    rfc(),
    dtc(),
]
classifier_names = [
    'K nearest neighbors',
    'Random Forest Classifier',
    'Decision Tree Classifier'
]

# %%
from sklearn import linear_model as lm
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeClassifier as dtc
from sklearn.neighbors import KNeighborsClassifier as knnc
from sklearn.ensemble import  RandomForestClassifier as rfc
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split 
fdtc(),
]
classifier_names = [
    'K nearest neighbors',
    'Random Forest Classifier',
    'Decision Tree Classifier'
]
for clf, clf_name in zip(classifiers, classifier_names):
    cv_scores = cross_val_score(clf, train[features], train[target], cv=5)
    print(clf_name, ' mean accuracy: ', round(cv_scores.mean()*100, 3), '% std: ', round(cv_scores.var()*100, 3),'%')
    models = []
models.append(('rfc',RandomForestClassifier()))
models.append(('Knnc', KNeighborsClassifier()))
models.append(('dTC', DecisionTreeClassifier()))
fig = plt.figure()
fig.suptitle('Algorithm Comparison')
ax = fig.add_subplot(111)
plt.boxplot(cv_scores)
ax.set_xticklabels(classifier_names)
plt.show()rom sklearn.metrics import accuracy_score, confusion_matrix
features = ['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness'\
            , 'BMI', 'Age', 'Insulin', 'DiabetesPedigreeFunction']
target = 'Outcome'
classifiers = [
    knnc(),
    rfc(),

# %%
y_hat_rfc = final_model_rfc.predict(test[features])
y_hat_dtc = final_model_dtc.predict(test[features])

print('test accuracy for random forest classifier '\
      , round(accuracy_score(test[target], y_hat_rfc)*100, 2), '%')
plt.title('Confusion matrix for random forest classifier')
sns.heatmap(confusion_matrix(test[target], y_hat_rfc), annot=True, cmap="Accent")
plt.xlabel('Predicted classes')
plt.ylabel('True Classes')
plt.show()

print('test accuracy for Decision tree classifier', \
      round(accuracy_score(test[target], y_hat_dtc)*100, 2),'%')
plt.title('confusion matrix for decision tree  classifier')
sns.heatmap(confusion_matrix(test[target], y_hat_dtc),annot=True,cmap="Accent")
plt.xlabel('Predicted classes')
plt.ylabel('True Classes')
plt.show()

# %%
from sklearn import linear_model as lm
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeClassifier as dtc
from sklearn.neighbors import KNeighborsClassifier as knnc
from sklearn.ensemble import  RandomForestClassifier as rfc
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split 
from sklearn.metrics import accuracy_score, confusion_matrix
features = ['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness'\
            , 'BMI', 'Age', 'Insulin', 'DiabetesPedigreeFunction']
target = 'Outcome'
classifiers = [
    knnc(),
    rfc(),
    dtc(),
]
classifier_names = [
    'K nearest neighbors',
    'Random Forest Classifier',
    'Decision Tree Classifier'
]
models_name = []
models_accuracy=[]
models_std=[]
for clf, clf_name in zip(classifiers, classifier_names):
    cv_scores = cross_val_score(clf, train[features], train[target], cv=5)
    print(clf_name, ' mean accuracy: ', round(cv_scores.mean()*100, 3), '% std: ', round(cv_scores.var()*100, 3),'%')
    models_name.append(clf_name)
    models_accuracy.append(round(cv_scores.mean()*100, 3))
    models_std.append(round(cv_scores.var()*100, 3))

# %%
import seaborn as sns
plt.figure(figsize=(10,6))
sns.barplot(models_name,models_accuracy)

# %%
final_model_rfc = rfc().fit(train[features], train[target])
final_model_dtc = dtc().fit(train[features], train[target])

# %%
y_hat_rfc = final_model_rfc.predict(test[features])
y_hat_dtc = final_model_dtc.predict(test[features])

print('test accuracy for random forest classifier '\
      , round(accuracy_score(test[target], y_hat_rfc)*100, 2), '%')
plt.title('Confusion matrix for random forest classifier')
sns.heatmap(confusion_matrix(test[target], y_hat_rfc), annot=True, cmap="Accent")
plt.xlabel('Predicted classes')
plt.ylabel('True Classes')
plt.show()

print('test accuracy for Decision tree classifier', \
      round(accuracy_score(test[target], y_hat_dtc)*100, 2),'%')
plt.title('confusion matrix for decision tree  classifier')
sns.heatmap(confusion_matrix(test[target], y_hat_dtc),annot=True,cmap="Accent")
plt.xlabel('Predicted classes')
plt.ylabel('True Classes')
plt.show()
